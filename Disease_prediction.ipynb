# %%
from tkinter import *
import numpy as np
import pandas as pd
from sklearn import svm
import csv
from collections import Counter
import tkinter.messagebox
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
#List of the symptoms is listed here in list l1.
l1=['back_pain','constipation','abdominal_pain','diarrhoea','mild_fever','yellow_urine',
'yellowing_of_eyes','acute_liver_failure','fluid_overload','swelling_of_stomach',
'swelled_lymph_nodes','malaise','blurred_and_distorted_vision','phlegm','throat_irritation',
'redness_of_eyes','sinus_pressure','runny_nose','congestion','chest_pain','weakness_in_limbs',
'fast_heart_rate','pain_during_bowel_movements','pain_in_anal_region','bloody_stool',
'irritation_in_anus','neck_pain','dizziness','cramps','bruising','obesity','swollen_legs',
'swollen_blood_vessels','puffy_face_and_eyes','enlarged_thyroid','brittle_nails',
'swollen_extremeties','excessive_hunger','extra_marital_contacts','drying_and_tingling_lips',
'slurred_speech','knee_pain','hip_joint_pain','muscle_weakness','stiff_neck','swelling_joints',
'movement_stiffness','spinning_movements','loss_of_balance','unsteadiness',
'weakness_of_one_body_side','loss_of_smell','bladder_discomfort','foul_smell_of urine',
'continuous_feel_of_urine','passage_of_gases','internal_itching','toxic_look_(typhos)',
'depression','irritability','muscle_pain','altered_sensorium','red_spots_over_body','belly_pain',
'abnormal_menstruation','dischromic _patches','watering_from_eyes','increased_appetite','polyuria','family_history','mucoid_sputum',
'rusty_sputum','lack_of_concentration','visual_disturbances','receiving_blood_transfusion',
'receiving_unsterile_injections','coma','stomach_bleeding','distention_of_abdomen',
'history_of_alcohol_consumption','fluid_overload','blood_in_sputum','prominent_veins_on_calf',
'palpitations','painful_walking','pus_filled_pimples','blackheads','scurring','skin_peeling',
'silver_like_dusting','small_dents_in_nails','inflammatory_nails','blister','red_sore_around_nose',
'yellow_crust_ooze']
#List of Diseases is listed in list disease.
disease=['Fungal infection','Allergy','GERD','Chronic cholestasis','Drug Reaction',
'Peptic ulcer diseae','AIDS','Diabetes','Gastroenteritis','Bronchial Asthma','Hypertension',
' Migraine','Cervical spondylosis',
'Paralysis (brain hemorrhage)','Jaundice','Malaria','Chicken pox','Dengue','Typhoid','hepatitis A',
'Hepatitis B','Hepatitis C','Hepatitis D','Hepatitis E','Alcoholic hepatitis','Tuberculosis',
'Common Cold','Pneumonia','Dimorphic hemmorhoids(piles)',
'Heartattack','Varicoseveins','Hypothyroidism','Hyperthyroidism','Hypoglycemia','Osteoarthristis',
'Arthritis','(vertigo) Paroymsal  Positional Vertigo','Acne','Urinary tract infection','Psoriasis',
'Impetigo']
prediction_1=" "
prediction_2=" "
prediction_3=" "
prediction_4=" "
prediction_5=" "
sc_svm=" "
sc_nb=" "
sc_rf=" "
sc_dt=" "
sc_knn=" "
Doctors_name=[]
l2=[]
for i in range(0,len(l1)):
    l2.append(0)

df=pd.read_csv("Prototype.csv")
#Replace the values in the imported file by pandas by the inbuilt function replace in pandas.
df.replace({'prognosis':{'Fungal infection':0,'Allergy':1,'GERD':2,'Chronic cholestasis':3,'Drug Reaction':4,
'Peptic ulcer diseae':5,'AIDS':6,'Diabetes ':7,'Gastroenteritis':8,'Bronchial Asthma':9,'Hypertension ':10,
'Migraine':11,'Cervical spondylosis':12,
'Paralysis (brain hemorrhage)':13,'Jaundice':14,'Malaria':15,'Chicken pox':16,'Dengue':17,'Typhoid':18,'hepatitis A':19,
'Hepatitis B':20,'Hepatitis C':21,'Hepatitis D':22,'Hepatitis E':23,'Alcoholic hepatitis':24,'Tuberculosis':25,
'Common Cold':26,'Pneumonia':27,'Dimorphic hemmorhoids(piles)':28,'Heart attack':29,'Varicose veins':30,'Hypothyroidism':31,
'Hyperthyroidism':32,'Hypoglycemia':33,'Osteoarthristis':34,'Arthritis':35,
'(vertigo) Paroymsal  Positional Vertigo':36,'Acne':37,'Urinary tract infection':38,'Psoriasis':39,
'Impetigo':40}},inplace=True)
#check the df 
#print(df.head())
X= df[l1]
#print(X)
y = df[["prognosis"]]
np.ravel(y)
#print(y)
#Read a csv named Testing.csv
tr=pd.read_csv("Prototype-1.csv")
#Use replace method in pandas.
tr.replace({'prognosis':{'Fungal infection':0,'Allergy':1,'GERD':2,'Chronic cholestasis':3,'Drug Reaction':4,
'Peptic ulcer diseae':5,'AIDS':6,'Diabetes ':7,'Gastroenteritis':8,'Bronchial Asthma':9,'Hypertension ':10,
'Migraine':11,'Cervical spondylosis':12,
'Paralysis (brain hemorrhage)':13,'Jaundice':14,'Malaria':15,'Chicken pox':16,'Dengue':17,'Typhoid':18,'hepatitis A':19,
'Hepatitis B':20,'Hepatitis C':21,'Hepatitis D':22,'Hepatitis E':23,'Alcoholic hepatitis':24,'Tuberculosis':25,
'Common Cold':26,'Pneumonia':27,'Dimorphic hemmorhoids(piles)':28,'Heart attack':29,'Varicose veins':30,'Hypothyroidism':31,
'Hyperthyroidism':32,'Hypoglycemia':33,'Osteoarthristis':34,'Arthritis':35,
'(vertigo) Paroymsal  Positional Vertigo':36,'Acne':37,'Urinary tract infection':38,'Psoriasis':39,
'Impetigo':40}},inplace=True)
X_test= tr[l1]
y_test = tr[["prognosis"]]
#print(y_test)
np.ravel(y_test)

def plotting():
    a=[sc_dt,sc_rf,sc_nb,sc_svm,sc_knn]
    algorithms = ["svm","Naive Bayes","K-Nearest Neighbors","Decision Tree","Random Forest"] 
    sns.set(rc={'figure.figsize':(15,8)})
    plt.xlabel("Algorithms")
    plt.ylabel("Accuracy score")
    sns.barplot(algorithms,a) 
def DecisionTree():
    global prediction_1
    global sc_dt
    from sklearn import tree
    clf3 = tree.DecisionTreeClassifier() 
    clf3 = clf3.fit(X,y)
    from sklearn.metrics import accuracy_score
    y_pred=clf3.predict(X_test)
    sc_dt= print(accuracy_score(y_test, y_pred))
    sc_dt1= print(accuracy_score(y_test, y_pred,normalize=False))
    
    psymptoms = [Symptom1.get(),Symptom2.get(),Symptom3.get(),Symptom4.get(),Symptom5.get()]
    for k in range(0,len(l1)):
        for z in psymptoms:
            if(z==l1[k]):
                l2[k]=1
    inputtest = [l2]
    predict = clf3.predict(inputtest)
    predicted=predict[0]
    h='no'
    for a in range(0,len(disease)):
        if(predicted == a):
            h='yes'
            break
    if (h=='yes'):
        t1.delete("1.0", END)
        t1.insert(END, disease[a])
        prediction_1=disease[a]
    else:
        t1.delete("1.0", END)
        t1.insert(END, "Not Found")
    plotting()    
def randomforest():
    global prediction_2
    global sc_rf
    from sklearn.ensemble import RandomForestClassifier
    clf4 = RandomForestClassifier()
    clf4 = clf4.fit(X,np.ravel(y))
    # calculating accuracy 
    from sklearn.metrics import accuracy_score
    y_pred=clf4.predict(X_test)
    sc_rf= print(accuracy_score(y_test, y_pred))
    sc_rf1=print(accuracy_score(y_test, y_pred,normalize=False))
    from sklearn.metrics import confusion_matrix
    matrix = confusion_matrix(y_test,y_pred)
    sns.heatmap(matrix,annot = True, fmt = "d")
    psymptoms = [Symptom1.get(),Symptom2.get(),Symptom3.get(),Symptom4.get(),Symptom5.get()]
    for k in range(0,len(l1)):
        for z in psymptoms:
            if(z==l1[k]):
                l2[k]=1
    inputtest = [l2]
    predict = clf4.predict(inputtest)
    predicted=predict[0]
    h='no'
    for a in range(0,len(disease)):
        if(predicted == a):
            h='yes'
            break
    if (h=='yes'):
        t2.delete("1.0", END)
        t2.insert(END, disease[a])
        prediction_2=disease[a]
    else:
        t2.delete("1.0", END)
        t2.insert(END, "Not Found")
    DecisionTree()
def NaiveBayes():
    global prediction_3
    global sc_nb
    from sklearn.naive_bayes import GaussianNB
    gnb = GaussianNB()
    gnb=gnb.fit(X,np.ravel(y))
    from sklearn.metrics import accuracy_score
    y_pred=gnb.predict(X_test)
    sc_nb=print(accuracy_score(y_test, y_pred))
    sc_nb1=print(accuracy_score(y_test, y_pred,normalize=False))
    psymptoms = [Symptom1.get(),Symptom2.get(),Symptom3.get(),Symptom4.get(),Symptom5.get()]
    for k in range(0,len(l1)):
        for z in psymptoms:
            if(z==l1[k]):
                l2[k]=1
    inputtest = [l2]
    predict = gnb.predict(inputtest)
    predicted=predict[0]
    h='no'
    for a in range(0,len(disease)):
        if(predicted == a):
            h='yes'
            break
    if (h=='yes'):
        t3.delete("1.0", END)
        t3.insert(END, disease[a])
        prediction_3=disease[a]
    else:
        t3.delete("1.0", END)
        t3.insert(END, "Not Found")
    randomforest()   
def Kneighbor():
    global prediction_4
    global sc_knn
    from sklearn.neighbors import KNeighborsClassifier
    clf5 = KNeighborsClassifier(n_neighbors = 8)
    clf5 = clf5.fit(X,np.ravel(y))
    from sklearn.metrics import accuracy_score
    y_pred=clf5.predict(X_test)
    sc_knn=print(accuracy_score(y_test, y_pred))
    sc_knn1=print(accuracy_score(y_test, y_pred,normalize=False))
    psymptoms = [Symptom1.get(),Symptom2.get(),Symptom3.get(),Symptom4.get(),Symptom5.get()]
    for k in range(0,len(l1)):
        for z in psymptoms:
            if(z==l1[k]):
                l2[k]=1
    inputtest = [l2]
    predict = clf5.predict(inputtest)
    predicted=predict[0]
    h='no'
    for a in range(0,len(disease)):
        if(predicted == a):
            h='yes'
            break
    if (h=='yes'):
        t4.delete("1.0", END)
        t4.insert(END, disease[a])
        prediction_4=disease[a]
    else:
        t4.delete("1.0", END)
        t4.insert(END, "Not Found")
    NaiveBayes()
def SupportVector():
    global prediction_5
    global sc_svm
    sc_svm=" "
    from sklearn.svm import SVC
    ml = SVC()
    ml = ml.fit(X,np.ravel(y))
    from sklearn.metrics import accuracy_score
    y_pred=ml.predict(X_test)
    sc_svm = print(accuracy_score(y_test, y_pred))
    sc_svm1=print(accuracy_score(y_test, y_pred,normalize=False))
    psymptoms = [Symptom1.get(),Symptom2.get(),Symptom3.get(),Symptom4.get(),Symptom5.get()]
    for k in range(0,len(l1)):
        for z in psymptoms:
            if(z==l1[k]):
                l2[k]=1
    inputtest = [l2]
    predict = ml.predict(inputtest)
    predicted=predict[0]
    h='no'
    for a in range(0,len(disease)):
        if(predicted == a):
            h='yes'
            break
    if (h=='yes'):
        t5.delete("1.0", END)
        t5.insert(END, disease[a])
        prediction_5=disease[a]
    else:
        t5.delete("1.0", END)
        t5.insert(END, "Not Found")
    Kneighbor() 
    

def Appointment():
    DERMATOLOGY = ['Fungal infection','Impetigo','Acne','Psoriasis']
    ALLERGISTS = ['Allergy','Drug Reaction','Bronchial Asthma']
    GASTROENTEROLOGY = ['GERD','Peptic ulcer diseae','Gastroenteritis','Jaundice','Alcoholic hepatitis']
    HEPATOLOGIST = ['Chronic cholestasis','Hepatitis A','hepatitis B','Hepatitis C','Hepatitis D','Hepatitis E']
    GENERALPHYSICIAN = ['AIDS','Common Cold']
    DIABETOLOGIST = ['Diabetes']
    CARDIOLOGIST = ['Hypertension','Heartattack']
    NEUROLOGIST = ['Migraine','Paralysis (brain hemorrhage)','(vertigo) Paroymsal  Positional Vertigo']
    ORTHOPAEDICIAN = ['Cervical spondylosis','Arthritis','Osteoarthristis']
    INFECTIONDISEASE = ['Malaria','Dengue']
    PAEDIATRICIAN = ['Chicken pox']
    ENDOCRINOLOGIST =['Typhoid','Hypothyroidism','Hypoglycemia']
    PULMONOLOGY = ['Tuberculosis','Pneumonia']
    UROLOGIST = ['Urinary tract infection']
    PROCTOLOGIST = ['Dimorphic hemmorhoids(piles)']
    RHEUMATOLOGIST = ['Varicoseveins']
    OPHTHALMOLOGIST = ['Hypothyroidism']
    ENTSPECIALIST = ['(vertigo) Paroymsal  Positional Vertigo']
    NEPHROLOGIST = ['Chronic cholestasis']
    
    L=[prediction_1,prediction_2,prediction_3,prediction_4,prediction_5]
    predicted = Counter(L).most_common(1)[0][0]
    
    global consultdoctor
    consultdoctor=" "
    
    if predicted in CARDIOLOGIST:
        consultdoctor = "CARDIOLOGIST"
        print(consultdoctor)
    elif predicted in UROLOGIST:
        consultdoctor = "UROLOGIST"
        print(consultdoctor)
    elif predicted in PULMONOLOGY:
        consultdoctor = "PULMONOLOGY"
        print(consultdoctor)
    elif predicted in ORTHOPAEDICIAN:
        consultdoctor = "ORTHOPAEDICIAN"
        print(consultdoctor)
    elif predicted in HEPATOLOGIST:
        consultdoctor = "HEPATOLOGIST"
        print(consultdoctor)
    elif predicted in DIABETOLOGIST:
        consultdoctor = "DIABETOLOGIST"
        print(consultdoctor)
    elif predicted in DERMATOLOGY:
        consultdoctor = "DERMATOLOGY"
        print(consultdoctor)
    elif predicted in ALLERGISTS:
        consultdoctor = "ALLERGISTS"
        print(consultdoctor)
    elif predicted in ENDOCRINOLOGIST:
        consultdoctor = "ENDOCRINOLOGIST" 
        print(consultdoctor)
    elif predicted in GASTROENTEROLOGY:
        consultdoctor = "GASTROENTEROLOGY" 
        print(consultdoctor)
    elif predicted in GENERALPHYSICIAN:
        consultdoctor = "GENERALPHYSICIAN"
        print(consultdoctor)
    elif predicted in NEUROLOGIST:
        consultdoctor = "NEUROLOGIST"
        print(consultdoctor)
    elif predicted in PAEDIATRICIAN:
        consultdoctor = "PAEDIATRICIAN"
        print(consultdoctor)
    elif predicted in INFECTIONDISEASE:
        consultdoctor = "INFECTIONDISEASE"
        print(consultdoctor)
    elif predicted in PROCTOLOGIST:
        consultdoctor = "PROCTOLOGIST"
        print(consultdoctor)
    elif predicted in RHEUMATOLOGIST:
        consultdoctor = "RHEUMATOLOGIST"
        print(consultdoctor)
    elif predicted in ENTSPECIALIST:
        consultdoctor = "ENTSPECIALIST"
        print(consultdoctor)
    elif predicted in OPHTHALMOLOGIST:
        consultdoctor = "OPHTHALMOLOGIST"
        print(consultdoctor)
    elif predicted in NEPHROLOGIST:
        consultdoctor = "NEPHROLOGIST"
        print(consultdoctor)    
    else:
        consultdoctor="other"
   
    
    f=open("DOCTORLISTEXCELCSV2.csv")
    c=1
    for row in csv.reader(f):
        if row[2]==consultdoctor:
            print(row)
            templist=row[2]
            Doctors_name.append(row[1])
            listBox.insert(c,row[1]+" "+row[3])
            listBoxnew.insert(c,row[3])
            c = c+1
def book():
    x=Doctors_name[listBox.curselection()[0]]
    messagebox.showinfo("Booking","Succesful appointment "+x+" contact no:8961913675/8337031341")
            
root = Tk()
root.geometry("1200x800")
  
# Add image file
bg = PhotoImage(file = "medical1.png")
  
# Create Canvas
canvas1 = Canvas( root, width = 1200,height = 800)
  
canvas1.pack(fill = "both", expand = True)
  
# Display image
canvas1.create_image( 0, 0,anchor = "nw",image=bg)


Symptom1 = StringVar()
Symptom1.set("Select Here")
Symptom2 = StringVar()
Symptom2.set("Select Here")
Symptom3 = StringVar()
Symptom3.set("Select Here")
Symptom4 = StringVar()
Symptom4.set("Select Here")
Symptom5 = StringVar()
Symptom5.set("Select Here")

Name = StringVar()
w2 = Label(canvas1, justify=LEFT, text="Disease Prediction using Machine Learning", fg="Red", bg="White")
w2.config(font=("Times",20,"bold italic"))
w2.grid(row=0, column=0, columnspan=2, padx=50)

S1Lb = Label(canvas1, text="Symptom 1", fg="Blue", bg="Pink")
S1Lb.config(font=("Times",15,"bold italic"))
S1Lb.grid(row=1, column=0, pady=10, sticky=W)

S2Lb = Label(canvas1, text="Symptom 2", fg="White", bg="#2E8B57")
S2Lb.config(font=("Times",15,"bold italic"))
S2Lb.grid(row=2, column=0, pady=10, sticky=W)

S3Lb = Label(canvas1, text="Symptom 3", fg="#2F4F4F",bg="white")
S3Lb.config(font=("Times",15,"bold italic"))
S3Lb.grid(row=3, column=0, pady=10, sticky=W)

S4Lb = Label(canvas1, text="Symptom 4", fg="blue", bg="Yellow")
S4Lb.config(font=("Times",15,"bold italic"))
S4Lb.grid(row=4, column=0, pady=10, sticky=W)

S5Lb = Label(canvas1, text="Symptom 5", fg="#C71585", bg="light green")
S5Lb.config(font=("Times",15,"bold italic"))
S5Lb.grid(row=5, column=0, pady=10, sticky=W)

drLb = Label(canvas1, text="DecisionTree", fg="white", bg="red")
drLb.config(font=("Times",15,"bold italic"))
drLb.grid(row=1, column=2, pady=10,sticky=W)

destreeLb = Label(canvas1, text="RandomForest", fg="black", bg="Orange")
destreeLb.config(font=("Times",15,"bold italic"))
destreeLb.grid(row=2, column=2, pady=10, sticky=W)

ranfLb = Label(canvas1, text="NaiveBayes", fg="#E6E6FA", bg="green")
ranfLb.config(font=("Times",15,"bold italic"))
ranfLb.grid(row=3, column=2, pady=10, sticky=W)

knnLb = Label(canvas1, text="K-Nearest", fg="#E6E6FA", bg="Black")
knnLb.config(font=("Times",15,"bold italic"))
knnLb.grid(row=4, column=2, pady=10, sticky=W)

svmLb = Label(canvas1, text="Support_vector", fg="Blue", bg="Red")
svmLb.config(font=("Times",15,"bold italic"))
svmLb.grid(row=5, column=2, pady=10, sticky=W)

OPTIONS = sorted(l1)

S1 = OptionMenu(canvas1, Symptom1,*OPTIONS)
S1.grid(row=1, column=0)

S2 = OptionMenu(canvas1, Symptom2,*OPTIONS)
S2.grid(row=2, column=0)

S3 = OptionMenu(canvas1, Symptom3,*OPTIONS)
S3.grid(row=3, column=0)

S4 = OptionMenu(canvas1, Symptom4,*OPTIONS)
S4.grid(row=4, column=0)

S5 = OptionMenu(canvas1, Symptom5,*OPTIONS)
S5.grid(row=5, column=0)


listBox = Listbox(canvas1,height=10,width=25,bg="grey",fg="white",selectmode=SINGLE)
listBox.grid(row=8, column=2)

listBoxnew = Listbox(canvas1,height=10,width=25,bg="grey",fg="white",selectmode=SINGLE)
listBoxnew.grid(row=8, column=3)

svm = Button(canvas1, text="Prediction", command=SupportVector,bg="#FFB6C1",fg="Red")
svm.config(font=("Times",15,"bold italic"))
svm.grid(row=3, column=1,padx=10)

ap = Button(canvas1, text="Doctor Appointment", command=Appointment,bg="Yellow",fg="Black")
ap.config(font=("Times",15,"bold italic"))
ap.grid(row=6, column=3,padx=10)

bk = Button(canvas1, text="Book", command=book,bg="pink",fg="black")
bk.config(font=("Times",15,"bold italic"))
bk.grid(row=9, column=1,padx=10)

t1 = Text(canvas1, height=1, width=20,bg="black",fg="red")
t1.config(font=("Times",15,"bold italic"))
t1.grid(row=1, column=3, padx=10)

t2 = Text(canvas1, height=1, width=20,bg="White",fg="Blue")
t2.config(font=("Times",15,"bold italic"))
t2.grid(row=2, column=3 , padx=10)

t3 = Text(canvas1, height=1, width=20,bg="red",fg="white")
t3.config(font=("Times",15,"bold italic"))
t3.grid(row=3, column=3 , padx=10)

t4 = Text(canvas1, height=1, width=20,bg="Yellow",fg="Black")
t4.config(font=("Times",15,"bold italic"))
t4.grid(row=4, column=3 , padx=10)

t5 = Text(canvas1, height=1, width=20,bg="Blue",fg="white")
t5.config(font=("Times",15,"bold italic"))
t5.grid(row=5, column=3, padx=10)
root.title("Disease Prediction System")
root.resizable(False,False)
root.mainloop()
# Out:
# 0.9512195121951219
# 39
# 0.926829268292683
# 38
# 0.9512195121951219
# 39
# 0.9512195121951219
# 39
# 0.9512195121951219
# 39
# ENDOCRINOLOGIST
# ['76', 'DrRPSINGHMBBSMDDM', 'ENDOCRINOLOGIST', 'WED 23:25', '1300']
# ['77', 'DrSUBIRRAYMBBSMDMRCP', 'ENDOCRINOLOGIST', 'MON 23:25', '1300']
# ['78', 'DrBKROYMBBSDMMDMRC', 'ENDOCRINOLOGIST', 'TUES 23:25', '1000']
# ['79', 'DrSAMBITDASMDDM', 'ENDOCRINOLOGIST', 'TUES 23:25', '1000']
# ['80', 'DrJJMUKHERJEEMDFRCP', 'ENDOCRINOLOGIST', 'FRI 8:25', '1200']
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-1-1962315c88e3>", line 364, in book
#     messagebox.showinfo("Booking","Succesful appointment "+x+" contact no:8961913675/8337031341")
# NameError: name 'messagebox' is not defined
# Exception in Tkinter callback
# Traceback (most recent call last):
# ...
